# %% [markdown]
# # Задание
# * Скачать все вакансии СБЕРа с ХХ (у апи есть ограничение в 2000, а также captcha подумайте как их можно обойти)
# * Извлеките все описания этих вакансий
# * Создайте аналогичный vacancy DataFrame только добавьте поле skills
# * Переведите даты публикаций в datetime
# * Постройте график опубликованных вакансий по датам
# * Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
# * Найдите те вакансии с использованием python, которые вам интересны
# * Определите по полю skills какие навыки больше всего востребованы для этих вакансий
# * Постройте график наиболее востребованных навыков для аналитика данных

# %% [markdown]
# https://github.com/hhru/api

# %%
import requests
import json
from tqdm.auto import tqdm
from collections import defaultdict
import pickle
import pandas as pd

# %%
sber = '3529'
page = 1
num_per_page = 100
moscow = 1
url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={page}&per_page={num_per_page}&area={moscow}'

# %%
res = requests.get(url)

# %%
res.json()
# Out:
# {'items': [{'id': '66634517',
#    'premium': False,
#    'name': 'JavaScript Developer (react)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 150000, 'to': 150000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Вавилова',
#     'building': '19',
#     'description': None,
#     'lat': 55.699314,
#     'lng': 37.580409,
#     'raw': 'Москва, улица Вавилова, 19',
#     'metro': {'station_name': 'Ленинский проспект',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.74',
#      'line_id': '6',
#      'lat': 55.70678,
#      'lng': 37.58499},
#     'metro_stations': [{'station_name': 'Ленинский проспект',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.74',
#       'line_id': '6',
#       'lat': 55.70678,
#       'lng': 37.58499}],
#     'id': '147569'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-23T09:08:11+0300',
#    'created_at': '2022-06-23T09:08:11+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66634517',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66634517?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66634517/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66634517',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт коммерческой разработки фронтенда (React) от 6 месяцев. - Уверенное знание JavaScript. - Опыт работы с Node.js. - Знание CSS. Будет плюсом: - Опыт...',
#     'responsibility': 'Информация о проекте. HR-платформа СБЕРа - собственный продукт компании, который покрывает весь жизненный цикл. Работы с человеческим капиталом: подбор, обучение...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66589132',
#    'premium': False,
#    'name': 'Junior java-разработчик',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-03T16:09:51+0300',
#    'created_at': '2022-06-03T16:09:51+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66589132',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66589132?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66589132/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66589132',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Java SE 8/11. Spring framework. MyBatis. React. Высшее законченное техническое образование (это важно!). Уверенное знание Java Core (опыт работы...',
#     'responsibility': 'Мы разрабатываем системы управления кредитными и операционными рисками для Блока «Риски» Сбербанка. Мы минимизируем кредитные риски банка, тем самым уменьшая...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66621399',
#    'premium': False,
#    'name': 'Методолог',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T11:59:42+0300',
#    'created_at': '2022-06-06T11:59:42+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66621399',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66621399?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66621399/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66621399',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание современных образовательных форматов, алгоритмов проектирования образовательного контента. Опыт работы методологом — от 5 лет. Умение действовать не по шаблону и...',
#     'responsibility': 'Разрабатывать образовательные программы, в том числе, сценарии к видео, тексты для экспертов, методические материалы для обучающихся - ядро образовательной программы. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66523856',
#    'premium': False,
#    'name': 'Аналитик SQL',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-23T18:15:56+0300',
#    'created_at': '2022-06-23T18:15:56+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66523856',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66523856?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66523856/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66523856',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (математика/физика/программирование/экономика). - Знания SQL. - Навыки работы с Python (приветствуется).',
#     'responsibility': 'Блок "Сеть продаж" курирует все физические каналы касания клиента с экосистемой (отделения, банкоматы, агентская сеть и тд). Мы разрабатываем и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54009192',
#    'premium': False,
#    'name': 'Инженер по сопровождению Hadoop (SberData)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-08T18:51:05+0300',
#    'created_at': '2022-06-08T18:51:05+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54009192',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54009192?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/54009192/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54009192',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с Linux на уровне пользователя (понимание устройства ОС, умение работать в консоли) от 2 лет. Опыт работы с...',
#     'responsibility': 'Администрирование и сопровождение Сервиса Сервисные сообщения КАП в аналитической платформе – 2-я линия сопровождения. Решение инцидентов, обработка запросов на обслуживание...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66589225',
#    'premium': False,
#    'name': 'Тестировщик',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-15T14:08:05+0300',
#    'created_at': '2022-06-15T14:08:05+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66589225',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66589225?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66589225/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66589225',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Готовить данные для локального тестового контура. Чтобы быстро влиться в проект мы ожидаем от тебя не меньше 2-х лет...',
#     'responsibility': 'Предстоит применять контрактное тестирование API и смотреть в БД. Проверка UI, браузеры только на chromium. Есть мобильное приложение на iOS. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66698926',
#    'premium': False,
#    'name': 'Java разработчик (Social & Salary Solutions)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-08T12:42:54+0300',
#    'created_at': '2022-06-08T12:42:54+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66698926',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66698926?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66698926/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66698926',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Технические компетенции: Java 8-11, Spring, Maven, Jenkins, Pipeline, Docker, Kubernetes, микросервисы, JUnit. (Есть возможность, при желании писать на Kotlin).',
#     'responsibility': 'Мы ищем Java разработчика в команду развития Social good сервисов для получения различных государственных услуг в один click. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67297641',
#    'premium': False,
#    'name': 'QA engineer',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-28T15:38:51+0300',
#    'created_at': '2022-06-28T15:38:51+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67297641',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67297641?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67297641/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67297641',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт в ручном тестировании от 1 года. - Уверенное знание принципов и методологий тестирования. - Уверенные знания по работе c JIRA. - ',
#     'responsibility': 'Ручное тестирование web и mobile приложений.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66546421',
#    'premium': False,
#    'name': 'С++ Developer',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'МЦК',
#      'station_id': '95.536',
#      'line_id': '95',
#      'lat': 55.740833,
#      'lng': 37.533333},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '823806'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-14T13:41:21+0300',
#    'created_at': '2022-06-14T13:41:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66546421',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66546421?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66546421/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66546421',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Хорошее знание STL. Знание C и C++11/14/17. Разработка API для библиотек и программных компонентов. Опыт производства чистого...',
#     'responsibility': 'Разработка новых и развитие существующих биометрических систем. Адаптация разработанных решений по разные платформы. Взаимодействие с R&D, аналитиками, инженерами технической...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66994541',
#    'premium': False,
#    'name': 'Product Owner направления монетизации Цифровые поверхности Салют (SberDevices)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'МЦК',
#      'station_id': '95.536',
#      'line_id': '95',
#      'lat': 55.740833,
#      'lng': 37.533333},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '823806'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-20T13:51:27+0300',
#    'created_at': '2022-06-20T13:51:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66994541',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66994541?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66994541/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66994541',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Способны организовать работу над продуктом вместе со смежными командами. Умеете анализировать тенденции и рынок данных, находить нестандартные решения и опираться...',
#     'responsibility': 'Формировать требования к продукту на основе анализа рынка, конкурентной среды и потребностей пользователей. Растить базу платящей аудитории на устройстве, продумывать...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66919453',
#    'premium': False,
#    'name': 'Инцидент-менеджер',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-16T17:33:14+0300',
#    'created_at': '2022-06-16T17:33:14+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66919453',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66919453?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66919453/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66919453',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование/опыт работы по направлению «Информационные технологии». Ответственность, высокий уровень самоорганизации. Нацеленность на результат. Коммуникабельность. Опыт работы с продуктами...',
#     'responsibility': 'Следить, чтобы «все было хорошо» - обеспечить оперативный, проактивный мониторинг качества предоставления бизнес-операций и ИТ-услуг нашей платформы. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55593434',
#    'premium': False,
#    'name': 'Программист С++',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'МЦК',
#      'station_id': '95.536',
#      'line_id': '95',
#      'lat': 55.740833,
#      'lng': 37.533333},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '823806'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-19T16:25:06+0300',
#    'created_at': '2022-06-19T16:25:06+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55593434',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55593434?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55593434/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55593434',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': "Готовы рассматривать кандидатов с хорошим уровнем опыта (Middle+). Стек технологий: С++'17, STL. Linux, Android, Windows. BSD sockets API. ",
#     'responsibility': 'Сетью с низкими задержками. Видео и аудио кодеками.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '53924933',
#    'premium': False,
#    'name': 'QA Engineer',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-14T10:46:01+0300',
#    'created_at': '2022-06-14T10:46:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=53924933',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/53924933?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/53924933/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/53924933',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Разработка автотестов (если нет опыта – обучим). Наши ожидания от кандидата: - Знания теории тестирования, подходов к разработке. - Общее понимание веб-технологий...',
#     'responsibility': 'В наших планах увеличение количества школ и следующие доработки: повышение производительности платформы для обеспечения одновременной работы сотен тысяч людей, развитие...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66640718',
#    'premium': False,
#    'name': 'Специалист C&B',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T18:31:32+0300',
#    'created_at': '2022-06-06T18:31:32+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66640718',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66640718?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66640718/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66640718',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в компаниях с выстроенным процессом performance management. Опыт разработки или внедрения изменений систем мотивации для различных категорий персонала. ',
#     'responsibility': 'Исследовать имеющиеся системы мотивации, определять направления совершенствования для различных категорий персонала, внедрять обновленные стандарты мотивации. Работать с обзорами заработных плат...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66617649',
#    'premium': False,
#    'name': 'Старший юрисконсульт (Направление правового обеспечения микро и малого бизнеса)',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T11:01:29+0300',
#    'created_at': '2022-06-06T11:01:29+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66617649',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66617649?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66617649/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66617649',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее юридическое образование (гражданско-правовая специализация). Опыт работы в направлении гражданское/корпоративное/банковское право от 1 года. Опыт правового сопровождения...',
#     'responsibility': 'Проведение правовой экспертизы документов, операций, сделок или контрагентов. Подготовка правовых заключений по существенным вопросам для последующего согласования руководством. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66938451',
#    'premium': False,
#    'name': 'Системный аналитик (Social good)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-17T11:59:16+0300',
#    'created_at': '2022-06-17T11:59:16+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66938451',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66938451?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66938451/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66938451',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Имел опыт разработки и согласования функциональных требований, документации по интеграционным взаимодействиям. Знал основы архитектуры веб-приложений и интеграционных взаимодействий. ',
#     'responsibility': 'Мы ищем cистемного аналитика в команду развития Social good сервисов, необходимых для быстрого получения различных государственных услуг на базе Сбербанк...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67006080',
#    'premium': False,
#    'name': 'Инженер по работе с договорами коммунальных услуг',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-20T16:54:11+0300',
#    'created_at': '2022-06-20T16:54:11+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67006080',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67006080?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67006080/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67006080',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Общий стаж работы по направлению эксплуатация/строительство не менее 1 года. Высшее образование (желательно техническое/экономическое). Приветствуется опыт работы в...',
#     'responsibility': 'Работа с договорами коммунальных услуг (заключение, сопровождение, оплата, контроль сроков). Взаимодействие с внутренними клиентами. Взаимодействие с внешними клиентами, контрагентами, надзорными...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67080364',
#    'premium': False,
#    'name': 'Frontend-разработчик',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-22T12:43:01+0300',
#    'created_at': '2022-06-22T12:43:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67080364',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67080364?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67080364/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67080364',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание TypeScript от 2-3 лет. Опыт разработки web-решений в команде от 5 лет. Знание ReactJS. Знание HTML, CSS. ',
#     'responsibility': 'Разработка клиентского кода на языке TypeScript/JavaScript. Разработка UI по существующему UI Kit (используем Ant Design). Участие в разработке архитектуры...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55475765',
#    'premium': False,
#    'name': 'UX/UI дизайнер',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-14T17:05:01+0300',
#    'created_at': '2022-06-14T17:05:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55475765',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55475765?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55475765/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55475765',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы дизайнером интерфейсов от 3-х лет. Наличие портфолио. Знание программ Sketch, Figma + желательно Zeplin, Invision, Axure, Principle...',
#     'responsibility': 'Решения СберПраво для B2B-сегмента представляют интеллектуальные LegalTech-сервисы, которые позволят автоматизировать операционные задачи и освободить время для...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55421333',
#    'premium': False,
#    'name': 'Технический руководитель',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-23T18:00:50+0300',
#    'created_at': '2022-06-23T18:00:50+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55421333',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55421333?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55421333/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55421333',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Имеете опыт принятия архитектурных решений. Имеете опыт руководства техническими специалистами. Имеете опыт выявления и закрытия технологических рисков. Принимали участие во...',
#     'responsibility': 'Нести ответственность за техническое состояние и стабильную работу АС. Взаимодействовать с проектными командами. Принимать руководящие решения, касающиеся сотрудников. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66494415',
#    'premium': False,
#    'name': 'Инженер-разработчик firmware',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-10T10:43:18+0300',
#    'created_at': '2022-06-10T10:43:18+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66494415',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66494415?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66494415/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66494415',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее техническое образование. Знание цифровой и аналоговой схемотехники. Знание и понимание принципов работы электронных схем. Знание и понимание принципов работы...',
#     'responsibility': 'Разработка цифровых/аналоговых устройств, в том числе с применением микроконтроллеров. Составление/чтение электрических принципиальных схем. Подбор и заказ элементной базы. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66725968',
#    'premium': False,
#    'name': 'Разработчик электронных учебных материалов',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-09T10:18:57+0300',
#    'created_at': '2022-06-09T10:18:57+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66725968',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66725968?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66725968/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66725968',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (желательно в сфере IT). Опыт разработки учебных материалов по IT - тематике от 2-х лет. Уверенные знания iSpring...',
#     'responsibility': 'Разработка учебных материалов для сотрудников компании. Разработка регламентов учебных материалов. Поддержка разработанных курсов. Взаимодействие с UI/UX дизайнером для уточнения...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66920148',
#    'premium': False,
#    'name': 'Инженер технической поддержки',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
# ...
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-30T12:04:48+0300',
#    'created_at': '2022-06-30T12:04:48+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48624489',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48624489?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/48624489/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48624489',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Вместе формируем единые правила, гайды, стили и инструменты. Быстро растём за счёт высокого качества Code Review. Декларативная верстка на UIKit...',
#     'responsibility': 'Дизайн-система и Backend-driven UI. Уже разрабатывали под iOS.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55904336',
#    'premium': False,
#    'name': 'Системный инженер',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-08T16:55:24+0300',
#    'created_at': '2022-06-08T16:55:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55904336',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55904336?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55904336/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55904336',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Владение методологией ITSM. Опыт администрирования/поддержки автоматизированных систем. Наличие практического опыта разработки эксплуатационных требований к АС. Внедрение и сопровождение промышленной...',
#     'responsibility': 'Администрирование ИТ-услуг. Обеспечение бесперебойного круглосуточного функционирования сопровождаемой АС. Осуществляет работы по внедрению и сопровождению администрируемых ИТ услуг, в первую...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66633113',
#    'premium': False,
#    'name': 'Data Analyst',
#    'department': {'id': '3529-3529-data', 'name': 'Сбер. Data Science'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T15:20:59+0300',
#    'created_at': '2022-06-06T15:20:59+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66633113',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66633113?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66633113/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66633113',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы аналитиком в крупном банке/аналогичной компании. Понимание работы банковского бизнеса. Уверенное знание SQL (уровень выше среднего). ',
#     'responsibility': 'Помогаем росту бизнеса через анализ корпоративной клиентской базы Сбера и конкурентов. Выстраиваем системные аналитические решения. Проводить анализ корпоративных клиентов в...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67010163',
#    'premium': False,
#    'name': 'Middle/Senior Frontend-разработчик',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-20T17:58:16+0300',
#    'created_at': '2022-06-20T17:58:16+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67010163',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67010163?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67010163/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67010163',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с React и Typescript от 2х лет. Знание HTML, CSS, SCCS, SVG, BEM. Умение работать с Git...',
#     'responsibility': 'Разработка фронта для сервиса Единый Кредитный Портфель (Mission Critical система для сопровождения кредитных сделок физ.лиц). Участие в проработке решений для...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66933327',
#    'premium': False,
#    'name': 'Data Engineer / Data Analyst (SberData)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-17T10:27:36+0300',
#    'created_at': '2022-06-17T10:27:36+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66933327',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66933327?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66933327/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66933327',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Навыки работы с Git или другой системой управления версиями. Оыпт работы Bash скриптами. Опыт работы с Hadoop (HDFS, Hive, Oozie...',
#     'responsibility': 'Формирование файлов конфигураций/инвентори. Создание и разворачивание дистрибутивов и плагинов для загрузки данных на различные контуры (от DEV до PROM...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66652790',
#    'premium': False,
#    'name': 'Ведущий инженер по тестированию Linux (QA)',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-07T09:49:21+0300',
#    'created_at': '2022-06-07T09:49:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66652790',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66652790?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66652790/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66652790',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание методов и методик тестирования. Опыт работы и сопровождения операционной системы Linux. Опыт работы в командной строке linux-подобных операционных...',
#     'responsibility': 'Обнаружение, документирование и отслеживание дефектов операционных систем Linux. Участие в работе команды (разработчкики, аналитики).'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67166741',
#    'premium': False,
#    'name': 'Методолог ИТ процессов / Процессный менеджер',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Новоданиловская набережная',
#     'building': '10',
#     'description': None,
#     'lat': 55.695905,
#     'lng': 37.625361,
#     'raw': 'Москва, Новоданиловская набережная, 10',
#     'metro': {'station_name': 'Тульская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.142',
#      'line_id': '9',
#      'lat': 55.70961,
#      'lng': 37.622569},
#     'metro_stations': [{'station_name': 'Тульская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.142',
#       'line_id': '9',
#       'lat': 55.70961,
#       'lng': 37.622569}],
#     'id': '146841'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-24T15:46:47+0300',
#    'created_at': '2022-06-24T15:46:47+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67166741',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67166741?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67166741/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67166741',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в ИТ от 2х лет. Опыт работы с технической и системной документацией и методологией процессов. ',
#     'responsibility': 'Разработка всех типов технической и системной документации в ИТ-компании. Ведение аналитической работы в ИТ-компании, разработка и поддержка аналитической...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False}],
#  'found': 1167,
#  'pages': 12,
#  'per_page': 100,
#  'page': 1,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?area=1&control_flag=vacancyBlacklistJoinEnabled%3ATrue&employer_id=3529&enable_snippets=true&items_on_page=100&page=1'}

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
num_pages
# Out:
# 12

# %%
v = vacancies.get('items')

# %%
# v[0].get('')

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
vacancy_ids = [el.get('id') for el in vacancies.get('items')]

# %%
vacancies.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'per_page', 'page', 'clusters', 'arguments', 'alternate_url'])

# %%
vnum  = vacancies.get('pages')

# %%
all_vacancy_ids= []
for i in tqdm(range(vnum)):
    url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={i}&per_page={num_per_page}&area={moscow}'
    res = requests.get(url)
    vacancies = res.json()
    vacancy_ids = [el.get('id') for el in vacancies.get('items')]
    all_vacancy_ids.extend(vacancy_ids)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
len(all_vacancy_ids)
https://api.hh.ru/vacancies/66634517
# Out:
# 1173

# %%
url = f'https://api.hh.ru/vacancies/{all_vacancy_ids[0]}'

# %%
res = requests.get(url)

# %%
res.json().get('key_skills')
# Out:
# []
